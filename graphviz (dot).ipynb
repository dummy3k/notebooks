# %%
# http://graphviz.readthedocs.org/en/latest/manual.html
from graphviz import Graph
h = Graph('hello', format='svg')
h.edge('Hello', 'World')
#print(h.pipe().decode('utf-8'))  
#h._repr_svg_()
h

# %%
# Out:
# 'hello.gv.svg'
